# %% [markdown]
# <a href="https://colab.research.google.com/github/Azamat2023/BlogProject/blob/master/10_MA%CA%BCLUMOTLARGA_ISHLOV_BERISH_10_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/h4PPC71.png)
# #**10-modul. Maʼlumotlarga ishlov berish. Fayllar va maʼlumotlar ombori**
# #10.5. Fayldan oʻqish va unga yozish. HDF5
# **Bu vazifalarni bajargach, CSV, Excel va HDF5 formatlarida fayllarni oʻqish hamda saqlash, yaʼni data processing (ma’lumotlarga ishlov berish) koʻnikmasini oʻzlashtirasiz.**

# %% [markdown]
# #1-topshiriq
#
#
# 1.    Quyidagi link orqali maʼlumotlarni Pandas dataframeʼiga yuklab oling.
#
#   *   https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/data_date.csv
#
#
#
# 2.   Yuklab olingan maʼlumotlarni `aqi.csv` fayliga saqlang.
#
# 3. Saqlab olingan `aqi.csv` faylining oxirgi 5 ta qatorini oʻqing.
#
# Eslatma: fayl nomini `aqi.csv` deb saqlaganimizning sababi AQI – Air Quality Index, yaʼni havo sifati indeksi deganidir. Bizning maʼlumotlarimizda davlatlarning havo sifati haqidagi maʼlumotlar saqlangan!

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/data_date.csv"
#javobni shu yerda yozing.
df = pd.read_csv(url)
df.to_csv("aqi.csv")
aqi_csv = pd.read_csv("aqi.csv")
aqi_csv.tail()
# Out:
#        Unnamed: 0        Date                   Country    Status  AQI Value
# 18116       18116  2025-03-06  United States of America  Moderate         82
# 18117       18117  2025-03-06                Uzbekistan      Good         17
# 18118       18118  2025-03-06                   Vatican  Moderate         65
# 18119       18119  2025-03-06                 Venezuela      Good         11
# 18120       18120  2025-03-06                   Vietnam  Moderate         64

# %% [markdown]
# #2-topshiriq
# 1. Saqlab olingan `aqi.csv` faylidagi maʼlumotlarning faqat 2024-yilga tegishlisini excel faylga `aqi_2024.xlsx` koʻrinishida saqlab oling.
# 2. Saqlab olingan `aqi_2024.xlsx` faylidan Oʻzbekistonga tegishli maʼlumotni (qatorlarni) oʻqing.

# %%
#javobni shu yerda yozing.
aqi_csv[aqi_csv['Date'].str.startswith('2024')].to_excel("aqi_2024.xlsx")
df2 = pd.read_excel("aqi_2024.xlsx")
df2[df2['Country'] == 'Uzbekistan']
# Out:
#       Unnamed: 0.1  Unnamed: 0        Date     Country     Status  AQI Value
# 128          13114       13114  2024-06-06  Uzbekistan       Good         21
# 261          13247       13247  2024-06-06  Uzbekistan       Good         21
# 394          13380       13380  2024-06-13  Uzbekistan       Good         35
# 525          13511       13511  2024-06-20  Uzbekistan       Good         10
# 656          13642       13642  2024-06-27  Uzbekistan       Good         26
# 786          13772       13772  2024-07-04  Uzbekistan       Good         19
# 914          13900       13900  2024-07-11  Uzbekistan       Good         26
# 1043         14029       14029  2024-07-18  Uzbekistan       Good         42
# 1173         14159       14159  2024-07-25  Uzbekistan       Good         30
# 1302         14288       14288  2024-08-01  Uzbekistan       Good         45
# 1432         14418       14418  2024-08-08  Uzbekistan       Good         42
# 1562         14548       14548  2024-08-15  Uzbekistan       Good         26
# 1691         14677       14677  2024-08-22  Uzbekistan       Good         23
# 1819         14805       14805  2024-08-29  Uzbekistan   Moderate         56
# 1948         14934       14934  2024-09-05  Uzbekistan   Moderate         70
# 2075         15061       15061  2024-09-12  Uzbekistan       Good         45
# 2204         15190       15190  2024-09-19  Uzbekistan  Hazardous        500
# 2331         15317       15317  2024-09-26  Uzbekistan  Unhealthy        157
# 2450         15436       15436  2024-10-03  Uzbekistan       Good         34
# 2578         15564       15564  2024-10-10  Uzbekistan   Moderate         63
# 2700         15686       15686  2024-10-17  Uzbekistan  Unhealthy        195
# 2821         15807       15807  2024-10-24  Uzbekistan  Unhealthy        180
# 2941         15927       15927  2024-10-31  Uzbekistan  Unhealthy        153
# 3060         16046       16046  2024-11-07  Uzbekistan   Moderate         65
# 3179         16165       16165  2024-11-14  Uzbekistan  Unhealthy        151
# 3297         16283       16283  2024-11-21  Uzbekistan  Unhealthy        152
# 3419         16405       16405  2024-11-28  Uzbekistan       Good         38
# 3541         16527       16527  2024-12-05  Uzbekistan   Moderate         83
# 3663         16649       16649  2024-12-12  Uzbekistan   Moderate        100
# 3786         16772       16772  2024-12-19  Uzbekistan       Good         34
# 3907         16893       16893  2024-12-26  Uzbekistan   Moderate         98

# %% [markdown]
# #3-topshiriq
# 1. `aqi.csv` faylidagi maʼlumotlarni oʻrganib chiqsangiz, bu faylda 2022–2025-yillar oraligʻidagi havo sifati haqidagi maʼlumotlarni koʻrishingiz mumkin. Hozir sizga vazifa:
#   * `aqi_2022.csv`, `aqi_2023.csv`, `aqi_2024.csv`, `aqi_2025.csv`  fayllariga `aqi.csv` faylidagi maʼlumotlarning mos davrlarini saqlang. Misol uchun, `aqi_2022` fayli 2022-yildagi havo sifati haqidagi maʼlumotlarni oʻzida saqlaydi.

# %%
#javobni shu yerda yozing.
aqi_csv[aqi_csv['Date'].str.startswith('2022')].to_csv("aqi_2022.csv", index=False)
aqi_csv[aqi_csv['Date'].str.startswith('2023')].to_csv("aqi_2023.csv", index=False)
aqi_csv[aqi_csv['Date'].str.startswith('2024')].to_csv("aqi_2024.csv", index=False)
aqi_csv[aqi_csv['Date'].str.startswith('2025')].to_csv("aqi_2025.csv", index=False)

# %% [markdown]
# #4-topshiriq
# 1. Saqlab olingan `aqi_2022.csv`, `aqi_2023.csv`, `aqi_2024.csv`, `aqi_2025.csv`  fayllarini HDF5 formatida saqlang. Fayl nomini `aqi.h5` deb nomlang. Kalit (key) sifatida fayllarning yillarini bering. Misol uchun, key=2025.

# %%
#javobni shu yerda yozing.
hdfobj = pd.HDFStore('aqi.h5')
df2 = pd.read_csv("aqi_2022.csv")
df3 = pd.read_csv("aqi_2023.csv")
df4 = pd.read_csv("aqi_2024.csv")
df5 = pd.read_csv("aqi_2025.csv")

hdfobj.put("aqi_2022", df2)
hdfobj.put("aqi_2023", df3)
hdfobj.put("aqi_2024", df4)
hdfobj.put("aqi_2025", df5)

hdfobj.close()

# %% [markdown]
# #5-topshiriq
# 1. `aqi.h5` faylidan maʼlumotlarni oʻqing va 2025-yilga tegishli maʼlumotlarni yangi dataframeʼga saqlang.
# 2. `aqi.h5` faylida 2025-yilning qaysi oylari uchun maʼlumotlar bor? Shu oylar roʻyxatini ekranga chiqaring!

# %%
import numpy as np
#javobni shu yerda yozing.
np.unique(df5.Date.values)
# Out:
# array(['2025-01-02', '2025-01-09', '2025-01-16', '2025-01-23',
#        '2025-01-30', '2025-02-06', '2025-02-13', '2025-02-20',
#        '2025-02-27', '2025-03-06'], dtype=object)
